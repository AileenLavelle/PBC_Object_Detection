# %% [markdown]
# # Fine-Tune YOLOv11 for Boat Detection
#
# **Steps:**
# 1. Convert COCO annotations to YOLO format
# 2. Split data into train/validation sets
# 3. Fine-tune YOLOv11
# 4. Evaluate the fine-tuned model

# %% [markdown]
# ---
# ## Step 1: Install Dependencies

# %%
# !pip install -q opencv-python-headless
# !pip install -q ultralytics

# %% [markdown]
# ---
# ## Step 2: Import Libraries

# %%
import os
import json
import shutil
import random
from pathlib import Path

import cv2
import numpy as np
import matplotlib.pyplot as plt

from ultralytics import YOLO

print("Imports successful!")
# Out:
# Imports successful!

# %% [markdown]
# ---
# ## Step 3: Configure Paths

# %%
#Setting source paths
SOURCE_IMAGE_FOLDER = "/content/Jupiter_Inlet"
SOURCE_COCO_JSON = "/content/Jupiter_Inlet/_annotations.coco.json"

#Output folder for YOLO-format dataset
YOLO_DATASET_PATH = "/content/Jupiter_Inlet/yolo_dataset"

#Training configuration
TRAIN_SPLIT = 0.8  # 80% for training, 20% for validation
RANDOM_SEED = 42   # For reproducible splits

print(f"Source images: {SOURCE_IMAGE_FOLDER}")
print(f"Source annotations: {SOURCE_COCO_JSON}")
print(f"Output dataset: {YOLO_DATASET_PATH}")
# Out:
# Source images: /content/Jupiter_Inlet
# Source annotations: /content/Jupiter_Inlet/_annotations.coco.json
# Output dataset: /content/Jupiter_Inlet/yolo_dataset

# %% [markdown]
# ---
# ## Step 4: Convert COCO to YOLO Format
#
# YOLO uses a different annotation format than COCO:
# - **COCO**: `[x, y, width, height]` in pixels
# - **YOLO**: `[class_id, center_x, center_y, width, height]` normalized to 0-1
#
# Each image gets a `.txt` file with the same name containing its annotations.

# %%
def coco_to_yolo_format(coco_json_path, image_folder, output_folder, train_split=0.8, seed=42):
    """
    Convert COCO annotations to YOLO format and split into train/val sets.

    YOLO format per line: class_id center_x center_y width height
    All values normalized to 0-1 (except class_id which is integer)
    """

    # Load COCO annotations
    with open(coco_json_path) as f:
        coco_data = json.load(f)

    # Create output directories
    for split in ['train', 'val']:
        os.makedirs(os.path.join(output_folder, 'images', split), exist_ok=True)
        os.makedirs(os.path.join(output_folder, 'labels', split), exist_ok=True)

    # Build mappings
    # Image ID -> image info
    id_to_image = {img['id']: img for img in coco_data['images']}

    # Image ID -> list of annotations
    id_to_annotations = {}
    for ann in coco_data['annotations']:
        img_id = ann['image_id']
        if img_id not in id_to_annotations:
            id_to_annotations[img_id] = []
        id_to_annotations[img_id].append(ann)

    # Get list of image IDs and shuffle
    image_ids = list(id_to_image.keys())
    random.seed(seed)
    random.shuffle(image_ids)

    # Split into train/val
    split_idx = int(len(image_ids) * train_split)
    train_ids = set(image_ids[:split_idx])
    val_ids = set(image_ids[split_idx:])

    print(f"Total images: {len(image_ids)}")
    print(f"Training images: {len(train_ids)}")
    print(f"Validation images: {len(val_ids)}")

    # Process each image
    stats = {'train': 0, 'val': 0, 'annotations': 0}

    for img_id, img_info in id_to_image.items():
        # Determine split
        split = 'train' if img_id in train_ids else 'val'
        stats[split] += 1

        filename = img_info['file_name']
        img_width = img_info['width']
        img_height = img_info['height']

        # Copy image to output folder
        src_image_path = os.path.join(image_folder, filename)
        dst_image_path = os.path.join(output_folder, 'images', split, filename)

        if os.path.exists(src_image_path):
            shutil.copy(src_image_path, dst_image_path)
        else:
            print(f"Warning: Image not found: {src_image_path}")
            continue

        # Create YOLO label file
        label_filename = os.path.splitext(filename)[0] + '.txt'
        label_path = os.path.join(output_folder, 'labels', split, label_filename)

        annotations = id_to_annotations.get(img_id, [])

        with open(label_path, 'w') as f:
            for ann in annotations:
                stats['annotations'] += 1

                # COCO bbox: [x_min, y_min, width, height] in pixels
                # Convert to float in case values are strings
                bbox = [float(v) for v in ann['bbox']]
                x_min, y_min, bbox_width, bbox_height = bbox

                # Convert to YOLO format: [center_x, center_y, width, height] normalized
                center_x = (x_min + bbox_width / 2) / img_width
                center_y = (y_min + bbox_height / 2) / img_height
                norm_width = bbox_width / img_width
                norm_height = bbox_height / img_height

                # Class 0 = boat (YOLO classes are 0-indexed)
                class_id = 0

                # Write line
                f.write(f"{class_id} {center_x:.6f} {center_y:.6f} {norm_width:.6f} {norm_height:.6f}\n")

    # Create data.yaml configuration file
    yaml_content = f"""# YOLOv11 Dataset Configuration
# Auto-generated from COCO annotations

path: {output_folder}
train: images/train
val: images/val

# Class names
names:
  0: boat

# Number of classes
nc: 1
"""

    yaml_path = os.path.join(output_folder, 'data.yaml')
    with open(yaml_path, 'w') as f:
        f.write(yaml_content)

    print(f"\nConversion complete!")
    print(f"  Train images: {stats['train']}")
    print(f"  Val images: {stats['val']}")
    print(f"  Total annotations: {stats['annotations']}")
    print(f"  Config file: {yaml_path}")

    return yaml_path

# %%
# Run conversion
yaml_path = coco_to_yolo_format(
    coco_json_path=SOURCE_COCO_JSON,
    image_folder=SOURCE_IMAGE_FOLDER,
    output_folder=YOLO_DATASET_PATH,
    train_split=TRAIN_SPLIT,
    seed=RANDOM_SEED
)
# Out:
# Total images: 366
# Training images: 292
# Validation images: 74
#
# Conversion complete!
#   Train images: 292
#   Val images: 74
#   Total annotations: 1199
#   Config file: /content/Jupiter_Inlet/yolo_dataset/data.yaml

# %% [markdown]
# ---
# ## Step 5: Verify the Dataset
#
# Let's visualize a few samples to make sure the conversion worked correctly.

# %%
def visualize_yolo_annotation(image_path, label_path):
    """
    Visualize YOLO annotations on an image.
    """
    # Load image
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    h, w = img.shape[:2]

    # Load annotations
    boxes = []
    if os.path.exists(label_path):
        with open(label_path) as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) == 5:
                    class_id, cx, cy, bw, bh = map(float, parts)

                    # Convert from normalized to pixel coordinates
                    x1 = int((cx - bw/2) * w)
                    y1 = int((cy - bh/2) * h)
                    x2 = int((cx + bw/2) * w)
                    y2 = int((cy + bh/2) * h)

                    boxes.append((x1, y1, x2, y2))

    # Draw boxes
    for x1, y1, x2, y2 in boxes:
        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 3)

    return img, len(boxes)


# Visualize a few training samples
train_images_dir = os.path.join(YOLO_DATASET_PATH, 'images', 'train')
train_labels_dir = os.path.join(YOLO_DATASET_PATH, 'labels', 'train')

sample_images = os.listdir(train_images_dir)[:4]

fig, axes = plt.subplots(2, 2, figsize=(16, 12))
axes = axes.flatten()

for i, img_name in enumerate(sample_images):
    img_path = os.path.join(train_images_dir, img_name)
    label_path = os.path.join(train_labels_dir, img_name.replace('.jpg', '.txt').replace('.png', '.txt'))

    img, num_boxes = visualize_yolo_annotation(img_path, label_path)

    axes[i].imshow(img)
    axes[i].set_title(f'{img_name}\n{num_boxes} boats')
    axes[i].axis('off')

plt.suptitle('Training Samples with YOLO Annotations (Green Boxes)', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Step 6: Fine-Tune YOLOv11
#
# Now we'll fine-tune the pre-trained YOLOv11 model on your boat data.
#
# **Key parameters:**
# - `epochs`: Number of training passes (more = better, but slower)
# - `imgsz`: Image size for training (larger = better accuracy, more memory)
# - `batch`: Batch size (reduce if you run out of memory)
# - `patience`: Stop early if no improvement for this many epochs

# %%
# Base model to fine-tune
BASE_MODEL = "yolo11m.pt"

# Training parameters
EPOCHS = 100
IMAGE_SIZE = 1280
BATCH_SIZE = 5
PATIENCE = 20

# Output folder for trained model
PROJECT_NAME = "/workspaces/PBC_Object_Detection/yolo_training"
RUN_NAME = "jupiter_boats_v1"

print("Training configuration:")
print(f"  Base model: {BASE_MODEL}")
print(f"  Epochs: {EPOCHS}")
print(f"  Image size: {IMAGE_SIZE}")
print(f"  Batch size: {BATCH_SIZE}")
print(f"  Output: {PROJECT_NAME}/{RUN_NAME}")
# Out:
# Training configuration:
#   Base model: yolo11m.pt
#   Epochs: 100
#   Image size: 1280
#   Batch size: 5
#   Output: /workspaces/PBC_Object_Detection/yolo_training/jupiter_boats_v1

# %%
# Load pre-trained model
model = YOLO(BASE_MODEL)
print(f"Loaded {BASE_MODEL}")
# Out:
# Loaded yolo11m.pt

# %%
# Start training!


results = model.train(
    data=yaml_path,           # Path to data.yaml
    epochs=EPOCHS,            # Number of epochs
    imgsz=IMAGE_SIZE,         # Image size
    batch=BATCH_SIZE,         # Batch size
    patience=PATIENCE,        # Early stopping patience
    save=True,                # Save checkpoints
    project=PROJECT_NAME,     # Output folder
    name=RUN_NAME,            # Run name
    exist_ok=True,            # Overwrite if exists
    pretrained=True,          # Use pre-trained weights
    optimizer='auto',         # Optimizer (auto selects best)
    verbose=True,             # Show progress
    seed=42,                  # Random seed for reproducibility

    # Data augmentation (helps prevent overfitting with small datasets)
    augment=True,
    hsv_h=0.015,              # Hue augmentation
    hsv_s=0.7,                # Saturation augmentation
    hsv_v=0.4,                # Value augmentation
    degrees=10,               # Rotation augmentation
    translate=0.1,            # Translation augmentation
    scale=0.5,                # Scale augmentation
    fliplr=0.5,               # Horizontal flip probability
    mosaic=1.0,               # Mosaic augmentation
)

print("\n" + "="*50)
print("TRAINING COMPLETE!")
print("="*50)
# Out:
# Ultralytics 8.4.11 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=True, auto_augment=randaugment, batch=5, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/Jupiter_Inlet/yolo_dataset/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1280, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=jupiter_boats_v1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/workspaces/PBC_Object_Detection/yolo_training, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/workspaces/PBC_Object_Detection/yolo_training/jupiter_boats_v1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1411795  ultralytics.nn.modules.head.Detect           [1, 16, None, [256, 512, 512]]
# YOLO11m summary: 232 layers, 20,053,779 parameters, 20,053,763 gradients, 68.2 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3082.2±306.5 MB/s, size: 1207.3 KB)
# train: Scanning /content/Jupiter_Inlet/yolo_dataset/labels/train.cache... 292 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 292/292 64.5Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 853.2±1055.8 MB/s, size: 1213.1 KB)
# val: Scanning /content/Jupiter_Inlet/yolo_dataset/labels/val.cache... 74 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 74/74 4.3Mit/s 0.0s
# Plotting labels to /workspaces/PBC_Object_Detection/yolo_training/jupiter_boats_v1/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005078125), 112 bias(decay=0.0)
# Image sizes 1280 train, 1280 val
# Using 2 dataloader workers
# Logging results to /workspaces/PBC_Object_Detection/yolo_training/jupiter_boats_v1
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100        11G      3.245      10.06     0.9368         11       1280: 100% ━━━━━━━━━━━━ 59/59 1.4s/it 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.5s/it 11.7s
#                    all         74        217    0.00027     0.0276   0.000139   5.28e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      10.8G        3.5      3.485     0.9591         19       1280: 100% ━━━━━━━━━━━━ 59/59 1.2it/s 47.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.6s
#                    all         74        217    0.00406      0.194      0.002   0.000636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      10.9G      3.597      3.222     0.9411          5       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.6s
#                    all         74        217   6.01e-05    0.00461   3.05e-05   1.22e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      10.8G      3.491      2.786     0.9605          5       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      10.9G      3.428      2.434     0.8953         11       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 46.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.1it/s 3.8s
#                    all         74        217     0.0103     0.0184    0.00117   0.000471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      10.9G      3.395      2.254     0.8762          9       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.7s
#                    all         74        217      0.291      0.171      0.111     0.0284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      10.8G      3.189      2.102      0.869          5       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 46.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.1it/s 3.7s
#                    all         74        217     0.0509     0.0276    0.00391    0.00138
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      10.9G      3.189      1.864      0.904         15       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.1it/s 3.8s
#                    all         74        217       0.38      0.318      0.242     0.0854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      10.8G      3.064      1.898     0.8552         18       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.9it/s 4.3s
#                    all         74        217      0.444      0.243      0.208     0.0542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      10.9G      3.246      2.095      0.883          6       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.6s
#                    all         74        217      0.083     0.0876     0.0465    0.00943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      10.9G      3.185      1.971     0.8795          7       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.9it/s 4.1s
#                    all         74        217      0.187      0.175      0.108     0.0318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      10.9G      3.016       1.77     0.8291          9       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.7s
#                    all         74        217      0.427      0.258      0.245     0.0751
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      10.9G      2.961      1.677     0.8501         11       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.1it/s 3.8s
#                    all         74        217      0.493      0.295      0.283     0.0831
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      10.9G      2.875       1.69     0.8439          3       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.1it/s 3.8s
#                    all         74        217      0.526      0.323       0.31     0.0954
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      10.8G      2.921      1.619     0.8548          8       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.1it/s 3.8s
#                    all         74        217        0.4      0.272       0.22     0.0679
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      10.8G      2.997      1.609     0.8354         25       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.7s
#                    all         74        217      0.509      0.305      0.317      0.106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      10.8G      2.906      1.583     0.8467         15       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.4it/s 3.3s
#                    all         74        217      0.601       0.34      0.367      0.127
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      10.9G      2.869       1.65     0.8689          8       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.7s
#                    all         74        217      0.518      0.378       0.37      0.113
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      10.9G      2.871      1.642     0.8437          5       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217      0.531       0.34      0.336      0.131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      10.9G      2.995      1.576     0.8256          8       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.7s
#                    all         74        217      0.589      0.396      0.382      0.138
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      10.9G      2.785      1.572     0.8523          2       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.6s
#                    all         74        217      0.627      0.382      0.382      0.142
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      10.8G      2.802      1.552     0.8424          2       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.4s
#                    all         74        217      0.598      0.369      0.381       0.12
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      10.8G      2.686      1.475     0.8142          6       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217      0.706      0.373      0.412       0.15
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      10.9G      2.851      1.564     0.8298          8       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217       0.57       0.41      0.394      0.126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      10.8G      2.819      1.427     0.8331         23       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217      0.634      0.396      0.429      0.144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      10.9G      2.816      1.524     0.8131          4       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.1it/s 3.8s
#                    all         74        217      0.693      0.336      0.373       0.12
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      10.9G      2.848      1.445     0.8106         11       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.1it/s 3.8s
#                    all         74        217      0.572       0.35      0.367      0.126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      10.8G      2.817      1.448     0.8114          3       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.0it/s 4.0s
#                    all         74        217      0.537       0.41      0.408      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      10.9G       2.73      1.435     0.8331          8       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217       0.46      0.419      0.376      0.127
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      10.9G      2.774      1.425     0.8181          3       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 46.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217      0.639      0.419      0.439       0.16
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      10.8G       2.74      1.379     0.8189          5       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.1it/s 3.7s
#                    all         74        217       0.67      0.447      0.465      0.155
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      10.9G      2.682      1.297     0.7984          6       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217      0.641      0.387      0.415      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      10.9G      2.682      1.338     0.8029         10       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217      0.651      0.419      0.456      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      10.8G      2.701      1.314     0.8102         16       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.6s
#                    all         74        217      0.589      0.447      0.451      0.159
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      10.8G      2.678      1.336     0.7948          9       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.7s
#                    all         74        217       0.56      0.442      0.425      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      10.8G      2.717      1.343     0.8144          9       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.6s
#                    all         74        217      0.533      0.442       0.43      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      10.9G      2.665      1.306     0.8092          3       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217      0.593      0.442      0.455       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      10.8G      2.693      1.273     0.7951          6       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.0it/s 4.0s
#                    all         74        217      0.604      0.435      0.422      0.147
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      10.9G      2.733      1.315     0.8263          3       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.4s
#                    all         74        217      0.678      0.442      0.466      0.154
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      10.8G      2.646      1.252     0.8062          2       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.4it/s 3.4s
#                    all         74        217      0.508      0.447      0.441      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      10.9G      2.704      1.336     0.8167          5       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.7s
#                    all         74        217      0.641      0.479      0.493      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      10.9G      2.752      1.342      0.817         15       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.6s
#                    all         74        217      0.669      0.475      0.483      0.159
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      10.9G      2.624      1.274     0.8084         11       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217       0.62      0.479      0.505      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      10.9G      2.549      1.205     0.8062          5       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.6s
#                    all         74        217      0.781      0.452       0.53      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      10.9G      2.526      1.223     0.7969          5       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.6s
#                    all         74        217      0.721      0.465      0.511      0.184
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      10.9G      2.539      1.223     0.7921         10       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.4it/s 3.4s
#                    all         74        217      0.693      0.424      0.453      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      10.8G      2.561      1.221     0.8059         10       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.4s
#                    all         74        217        0.7      0.475      0.499      0.183
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      10.9G      2.648      1.299     0.7784          3       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.4it/s 3.4s
#                    all         74        217      0.681      0.472      0.498      0.186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      10.9G      2.662      1.246     0.7792         11       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.4s
#                    all         74        217      0.629       0.46      0.458      0.148
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      10.9G      2.717      1.344     0.7924          4       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.4s
#                    all         74        217      0.648      0.483      0.484       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      10.8G      2.541      1.214     0.8101         13       1280: 100% ━━━━━━━━━━━━ 59/59 1.2it/s 47.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217      0.621      0.512      0.519      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      10.9G      2.605      1.207     0.7832          4       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.4s
#                    all         74        217      0.689      0.488      0.511      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      10.8G      2.633      1.238     0.7945         11       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.6s
#                    all         74        217      0.669      0.396      0.435      0.164
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      10.9G      2.563      1.256     0.7909          4       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.4it/s 3.3s
#                    all         74        217      0.586      0.424      0.455      0.179
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      10.8G      2.619      1.294     0.7798         20       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217       0.58      0.502      0.497      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      10.9G      2.597      1.183     0.7803          2       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217      0.621      0.387      0.427      0.171
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      10.9G       2.53      1.181     0.8032         16       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.7s
#                    all         74        217      0.606      0.507      0.496      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      10.8G      2.491      1.169     0.7813         13       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.1it/s 3.9s
#                    all         74        217      0.683      0.484      0.497      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      10.8G      2.503       1.12     0.7735          4       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.1it/s 3.8s
#                    all         74        217      0.631      0.493      0.512      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      10.9G      2.493      1.131     0.8103          5       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217       0.69      0.493      0.536       0.21
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      10.8G      2.467      1.097     0.7796          8       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.2it/s 3.7s
#                    all         74        217       0.64      0.499      0.509      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      10.8G      2.627      1.222     0.7917          2       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.1it/s 3.8s
#                    all         74        217      0.605      0.442      0.458       0.14
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      10.9G      2.542      1.156     0.8019          5       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.4it/s 3.3s
#                    all         74        217      0.727      0.516      0.542      0.205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      10.8G      2.547      1.126     0.7898          9       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.4s
#                    all         74        217      0.589      0.493      0.474      0.164
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      10.9G      2.473        1.1     0.7918          6       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.1it/s 3.8s
#                    all         74        217      0.652      0.548      0.563      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      10.8G       2.49      1.108      0.794          7       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 45.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217      0.662      0.516       0.52      0.205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      10.8G      2.493      1.093     0.7994          4       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217      0.709      0.484      0.512      0.203
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      10.9G      2.433      1.104     0.7937          7       1280: 100% ━━━━━━━━━━━━ 59/59 1.3it/s 44.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.3it/s 3.5s
#                    all         74        217      0.768      0.479      0.556      0.205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      10.9G      2.404      1.029     0.7792         21       1280: 58% ━━━━━━╸───── 34/59 1.3it/s 27.0s<19.2s

# %% [markdown]
# ---
# ## Step 7: Locate the Best Model
#
# After training, the best model weights are saved automatically.

# %%
# Find the best model
best_model_path = os.path.join(PROJECT_NAME, RUN_NAME, 'weights', 'best.pt')
last_model_path = os.path.join(PROJECT_NAME, RUN_NAME, 'weights', 'last.pt')

if os.path.exists(best_model_path):
    print(f"Best model saved at: {best_model_path}")
else:
    print(f"Best model not found at expected path")
    print(f"Looking in {PROJECT_NAME}/{RUN_NAME}/weights/")

if os.path.exists(last_model_path):
    print(f"Last model saved at: {last_model_path}")
# Out:
# Best model saved at: /workspaces/PBC_Object_Detection/yolo_training/jupiter_boats_v1/weights/best.pt
# Last model saved at: /workspaces/PBC_Object_Detection/yolo_training/jupiter_boats_v1/weights/last.pt

# %% [markdown]
# ---
# ## Step 8: Evaluate the Fine-Tuned Model
#
# Let's see how much better our fine-tuned model performs compared to the pre-trained one.

# %%
# Load the fine-tuned model
finetuned_model = YOLO(best_model_path)
print(f"Loaded fine-tuned model: {best_model_path}")
# Out:
# Loaded fine-tuned model: /workspaces/PBC_Object_Detection/yolo_training/jupiter_boats_v1/weights/best.pt

# %%
# Run validation on the validation set
val_results = finetuned_model.val(
    data=yaml_path,
    imgsz=IMAGE_SIZE,
    batch=BATCH_SIZE,
    conf=0.25,
    iou=0.5,
    verbose=True
)

print("\n" + "="*50)
print("VALIDATION RESULTS")
print("="*50)
print(f"mAP@0.5: {val_results.box.map50:.3f}")
print(f"mAP@0.5:0.95: {val_results.box.map:.3f}")
print(f"Precision: {val_results.box.mp:.3f}")
print(f"Recall: {val_results.box.mr:.3f}")
# Out:
# Ultralytics 8.4.11 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 126 layers, 20,030,803 parameters, 0 gradients, 67.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4245.7±1754.6 MB/s, size: 1243.1 KB)
# val: Scanning /content/Jupiter_Inlet/yolo_dataset/labels/val.cache... 74 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 74/74 20.7Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 1.3it/s 7.7s
#                    all         74        217      0.686      0.272      0.497      0.194
# Speed: 3.6ms preprocess, 22.6ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to /content/runs/detect/val
#
# ==================================================
# VALIDATION RESULTS
# ==================================================
# mAP@0.5: 0.497
# mAP@0.5:0.95: 0.194
# Precision: 0.686
# Recall: 0.272

# %% [markdown]
# ---
# ## Step 9: Test on Sample Images
#
# Let's visually compare the fine-tuned model's predictions.

# %%
# Get validation images for testing
val_images_dir = os.path.join(YOLO_DATASET_PATH, 'images', 'val')
test_images = [os.path.join(val_images_dir, f) for f in os.listdir(val_images_dir) if f.endswith(('.jpg', '.png'))][:6]

print(f"Testing on {len(test_images)} validation images...")

# Run inference
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
axes = axes.flatten()

for i, img_path in enumerate(test_images):
    # Run detection
    results = finetuned_model(img_path, conf=0.25, verbose=False)

    # Get annotated image
    annotated = results[0].plot()
    annotated = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)

    # Count detections
    num_boats = len(results[0].boxes)

    axes[i].imshow(annotated)
    axes[i].set_title(f'{os.path.basename(img_path)}\nDetected: {num_boats} boats')
    axes[i].axis('off')

plt.suptitle('Fine-Tuned Model Predictions', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# Testing on 6 validation images...

# %% [markdown]
# ---
# ## Step 10: Use Fine-Tuned Model with SAHI

# %%
# Install SAHI if not already installed
# !pip install -q sahi

from sahi import AutoDetectionModel
from sahi.predict import get_sliced_prediction
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 12.4 MB/s eta 0:00:00

# %%
# Load fine-tuned model with SAHI
sahi_model = AutoDetectionModel.from_pretrained(
    model_type="ultralytics",
    model_path=best_model_path,
    confidence_threshold=0.25,
    device="cuda:0" if os.system("nvidia-smi > /dev/null 2>&1") == 0 else "cpu"
)

print("Fine-tuned model loaded with SAHI!")
# Out:
# Fine-tuned model loaded with SAHI!

# %%
# Test SAHI with fine-tuned model
test_image = test_images[0]

# Run sliced prediction
result = get_sliced_prediction(
    image=test_image,
    detection_model=sahi_model,
    slice_height=384,
    slice_width=384,
    overlap_height_ratio=0.4,
    overlap_width_ratio=0.4,
)

# Visualize
result.export_visuals(export_dir="/tmp/sahi_results")

# Load and display
result_img = cv2.imread("/tmp/sahi_results/prediction_visual.png")
result_img = cv2.cvtColor(result_img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(16, 12))
plt.imshow(result_img)
plt.title(f'SAHI + Fine-Tuned Model\nDetected: {len(result.object_prediction_list)} boats')
plt.axis('off')
plt.show()

print(f"\nDetected {len(result.object_prediction_list)} boats with SAHI sliced inference")
# Out:
# Performing prediction on 99 slices.
# Detected 17 boats with SAHI sliced inference

# %% [markdown]
# ---
# ## Step 11: Export Model Path for Your Detection Pipeline
#
# Copy this path to use in your boat detection notebook.

# %%
print("="*60)
print("YOUR FINE-TUNED MODEL")
print("="*60)
print(f"\nBest model path:")
print(f"  {best_model_path}")
print(f"\nTo use in your detection notebook, change MODEL_PATH to:")
print(f'  MODEL_PATH = "{best_model_path}"')
print("\n" + "="*60)
# Out:
# ============================================================
# YOUR FINE-TUNED MODEL
# ============================================================
#
# Best model path:
#   /workspaces/PBC_Object_Detection/yolo_training/jupiter_boats_v1/weights/best.pt
#
# To use in your detection notebook, change MODEL_PATH to:
#   MODEL_PATH = "/workspaces/PBC_Object_Detection/yolo_training/jupiter_boats_v1/weights/best.pt"
#
# ============================================================

# %% [markdown]
# ---
# ## Summary
#
# **What we did:**
# 1. Converted COCO annotations to YOLO format
# 2. Split data into training (80%) and validation (20%)
# 3. Fine-tuned YOLOv11m on your boat images
# 4. Evaluated the model performance
#
# **Expected improvements:**
# - Pre-trained model recall: ~10%
# - Fine-tuned model recall: ~70-90% (depending on data quality)
#
# **Tips for even better results:**
# 1. **More data**: Add images from different times, weather conditions
# 2. **More epochs**: Train longer if validation loss is still decreasing
# 3. **Larger image size**: Use `imgsz=1280` if you have enough GPU memory
# 4. **Larger model**: Try `yolo11l.pt` or `yolo11x.pt` for better accuracy
